# %%
# 용해로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=740:
        temp[i]=740
temp_melt = [20]*60 + temp + [740]*60

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*20 + temp + [50]*80

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = [0]*90 + temp + [100]*10

gas_use = [0]*40 + [10]*160

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": [20],#"온도(용탕)": temp_melt,
    "temp(air)": [20],#"온도(대기)": temp_air,
    "gas(melt)": [0],#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": [0],#"가스 발생량 측정(가열)": [i * 0.25 for i in range(0, 500, 5)]
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "meltingM"
    
    # JSON 파일로 저장
    file_name = f"meltingM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 유지로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*30
for i in range(30):
    temp[i] += 25*i
    if temp[i]>=740:
        temp[i]=740
temp2 = [740]*30
for i in range(30):
    temp2[i] -= 1.3*i
    if temp2[i]<=700:
        temp2[i]=700
temp_melt = [20]*60 + temp + [740]*30 + temp2 + [700]*50

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*60 + temp + [50]*40

temp = [0]*130
for i in range(130):
    temp[i] += 0.8*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = [0]*60 + temp + [100]*10

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": [20],#"온도(용탕)": temp_melt,
    "temp(air)": [20],#"온도(대기)": temp_air,
    "gas(melt)": [0],#"가스 발생량 측정(용탕)": list(range( 0, 1000, 10)),
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "holdingM"
    
    # JSON 파일로 저장
    file_name = f"holdingM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('holdingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 탈가스

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=700:
        temp[i]=700
temp_melt = [20]*90 + temp + [700]*30

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*100 + temp

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = [0]*90 + temp + [100]*10

gas_use = [0]*90 + [10]*110

filter_use = [11]*50 + [12]*150

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": [20],#"온도(용탕)": temp_melt,
    "temp(air)": [20],#"온도(대기)": temp_air,
    "gas(melt)": [0],#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": [0],#가스 사용량 (아르곤)
    "filter_use" : [11],
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "deGassingM"
    
    # JSON 파일로 저장
    file_name = f"deGassingM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('deGassingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 주조기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*40
for i in range(40):
    temp[i] += 10*i
    if temp[i]>=600:
        temp[i]=600
temp2 = [temp[39]]*40
for i in range(40):
    temp2[i] -= 1.3*i
    if temp2[i]<=20:
        temp2[i]=20
temp_melt = [20]*120 + temp + temp2

temp = [13]*80
for i in range(80):
    temp[i] += 0.2*i
    if temp[i]>=28:
        temp[i]=28
temp_cooler = [13]*120 + temp

temp = [0]*45
for i in range(45):
    temp[i] += 1*i
    if temp[i]>=600:
        temp[i]=600
temp2 = [temp[44]]*35
for i in range(35):
    temp2[i] -= 0.3*i
    if temp2[i]<=0:
        temp2[i]=0
gas_melt = [0]*120 + temp + temp2

#gas_use = [0]*120 + [10]*80

temp = [200]*25
for i in range(25):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[24]]*45
for i in range(45):
    temp2[i] -= 1*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*120 + temp + [temp[24]]*10 + temp2

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)" : [20],
    "temp(cooler)": [13],#냉각수온도
    "gas(melt)": [0],#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    #"gas_use": gas_use,#가스 교체주기(냉각로)
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    #row_dict["gas_use"] = "2024-04-01 00:00:00"
    row_dict["Name"] = "slabCasting"
    
    # JSON 파일로 저장
    file_name = f"slabCasting/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('slabCasting')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 냉간 압연기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=380:
        temp[i]=380
temp_melt = [20]*60 + temp + [380]*60

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*20 + temp + [50]*80

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = [0]*90 + temp + [100]*10

gas_use = [0]*40 + [10]*160

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*90 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*10 + temp2

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": [20],#"온도(용탕)": temp_melt,
    "temp(air)": [20],#"온도(대기)": temp_air,
    "gas(melt)": [0],#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": [0],#"가스 발생량 측정(가열)": [i * 0.25 for i in range(0, 500, 5)]
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "coldMillingM"
    
    # JSON 파일로 저장
    file_name = f"coldMillingM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#교정기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*40 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp

data = {
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "tensionLeveling"
    
    # JSON 파일로 저장
    file_name = f"tensionLeveling/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#폭 절단기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*40 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp

data = {
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "cuttingWidthM"
    
    # JSON 파일로 저장
    file_name = f"cuttingWidthM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#길이 절단기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*40 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp

data = {
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "cuttingLengthM"
    
    # JSON 파일로 저장
    file_name = f"cuttingLengthM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('cuttingLengthM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 소둔로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=410:
        temp[i]=410
temp_melt = [20]*60 + temp + [410]*60

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*20 + temp + [50]*80

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = [200]*40 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*10 + temp2 + [temp2[19]]*10 + temp + [temp[19]]*5 + temp2[:15]


data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": [20],#"온도(용탕)": temp_melt,
    "temp(air)": [20],#"온도(대기)": temp_air,
    "elec_use" : [200]
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "annellingM"
    
    # JSON 파일로 저장
    file_name = f"annellingM/Temps/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %% [markdown]
# import matplotlib.pyplot as plt
#
# up = list(range(0, 520, 5))
# #up_slope = list(range(1, 10000, 10))
#
# up_slope = up_slope[:50]
# for i in range(len(up_slope)):
#     up[i+10] += up_slope[i]
# for i in range(len(up[10+len(up_slope):])):
#     up[10+len(up_slope)+i] += up_slope[49]
