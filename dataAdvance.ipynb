# %%
# 용해로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=740:
        temp[i]=740
temp_melt = temp + [740]*120

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = temp + [50]*100

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = temp + [100]*100

gas_use = [10]*200

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": temp_melt,#"온도(용탕)": temp_melt,
    "temp(air)": temp_air,#"온도(대기)": temp_air,
    "gas(melt)": gas_melt,#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": gas_use,#"가스 발생량 측정(가열)": [i * 0.25 for i in range(0, 500, 5)]
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "meltingM"
    
    # JSON 파일로 저장
    file_name = f"meltingM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 유지로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*30
for i in range(30):
    temp[i] += 25*i
    if temp[i]>=740:
        temp[i]=740
temp2 = [740]*30
for i in range(30):
    temp2[i] -= 1.3*i
    if temp2[i]<=700:
        temp2[i]=700
temp_melt = temp + [740]*30 + temp2 + [700]*110

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = temp + [50]*100

temp = [0]*130
for i in range(130):
    temp[i] += 0.8*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = temp + [100]*70

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": temp_melt,#"온도(용탕)": temp_melt,
    "temp(air)": temp_air,#"온도(대기)": temp_air,
    "gas(melt)": gas_melt,#"가스 발생량 측정(용탕)": list(range( 0, 1000, 10)),
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "holdingM"
    
    # JSON 파일로 저장
    file_name = f"holdingM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('holdingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 탈가스

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=700:
        temp[i]=700
temp_melt = temp + [700]*120

temp = [20]*200 
for i in range(200):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = temp

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = temp + [100]*100

gas_use = [10]*200

filter_use = [12]*200

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]


data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": temp_melt,#"온도(용탕)": temp_melt,
    "temp(air)": temp_air,#"온도(대기)": temp_air,
    "gas(melt)": gas_melt,#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": gas_use,#가스 사용량 (아르곤)
    "filter_use" : filter_use,
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "deGassingM"
    
    # JSON 파일로 저장
    file_name = f"deGassingM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('deGassingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 주조기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*40
for i in range(40):
    temp[i] += 10*i
    if temp[i]>=600:
        temp[i]=600
temp2 = [temp[39]]*160
for i in range(160):
    temp2[i] -= 1.3*i
    if temp2[i]<=20:
        temp2[i]=20
temp_melt = temp + temp2

temp = [13]*200
for i in range(200):
    temp[i] += 0.2*i
    if temp[i]>=28:
        temp[i]=28
temp_cooler = temp

temp = [0]*105
for i in range(105):
    temp[i] += 1*i
    if temp[i]>=600:
        temp[i]=600
temp2 = [temp[104]]*95
for i in range(95):
    temp2[i] -= 0.3*i
    if temp2[i]<=0:
        temp2[i]=0
gas_melt = temp + temp2

#gas_use = [0]*120 + [10]*80

temp = [200]*25
for i in range(25):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[24]]*165
for i in range(165):
    temp2[i] -= 1*i
    if temp2[i]<=200:
        temp2[i]=200
elec_use = temp + [temp[24]]*10 + temp2

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)" : temp_melt,
    "temp(cooler)": temp_cooler,#냉각수온도
    "gas(melt)": gas_melt,#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    #"gas_use": gas_use,#가스 교체주기(냉각로)
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["gas_use"] = "2024-04-01 00:00:00"
    row_dict["Name"] = "slabCasting"
    
    # JSON 파일로 저장
    file_name = f"slabCasting/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('slabCasting')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 냉간 압연기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=380:
        temp[i]=380
temp_melt = temp + [380]*120

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = temp + [50]*100

temp = [0]*100
for i in range(100):
    temp[i] += 1*i
    if temp[i]>=100:
        temp[i]=100
gas_melt = temp + [100]*100

gas_use = [10]*200

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": temp_melt,#"온도(용탕)": temp_melt,
    "temp(air)": temp_air,#"온도(대기)": temp_air,
    "gas(melt)": gas_melt,#"가스 발생량 측정(용탕)": list(range(0, 1000, 10)),
    "gas_use": gas_use,#"가스 발생량 측정(가열)": [i * 0.25 for i in range(0, 500, 5)]
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "coldMillingM"
    
    # JSON 파일로 저장
    file_name = f"coldMillingM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#교정기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "tensionLeveling"
    
    # JSON 파일로 저장
    file_name = f"tensionLeveling/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#폭 절단기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "cuttingWidthM"
    
    # JSON 파일로 저장
    file_name = f"cuttingWidthM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
#길이 절단기

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = [temp2[19]]*10 + temp + [temp[19]]*10 + temp2
elec_use =  ttemp*3 + [temp2[19]]*10 + temp[:10]

data = {
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "cuttingLengthM"
    
    # JSON 파일로 저장
    file_name = f"cuttingLengthM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('cuttingLengthM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %%
# 소둔로

import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

temp = [20]*80 #list(range(20, 221, 5))
for i in range(80):
    temp[i] += 9*i
    if temp[i]>=410:
        temp[i]=410
temp_melt = [20]*60 + temp + [410]*60

temp = [20]*100 
for i in range(100):
    temp[i] += 0.3*i
    if temp[i]>=50:
        temp[i]=50
temp_air = [20]*20 + temp + [50]*80

temp = [200]*20
for i in range(20):
    temp[i] += 35*i
    if temp[i]>=900:
        temp[i]=900
temp2 = [temp[19]]*20
for i in range(20):
    temp2[i] -= 35*i
    if temp2[i]<=200:
        temp2[i]=200
ttemp = temp + [temp[19]]*10 + temp2 + [temp2[19]]*10
elec_use = ttemp*2 + temp + [temp[19]]*5 + temp2 + [temp2[19]]*5 + temp + [temp[19]]*5 + temp2[:5]


data = {
    #"타임스탬프": pd.date_range(start="2024-04-01 00:00:00", periods=100, freq="s"),
    "temp(melt)": temp_melt,#"온도(용탕)": temp_melt,
    "temp(air)": temp_air,#"온도(대기)": temp_air,
    "elec_use" : elec_use
}

df = pd.DataFrame(data)

# 각 행을 JSON 파일로 저장
for index, row in df.iterrows():
    # 각 행을 딕셔너리로 변환
    row_dict = row.to_dict()
    
    # 원하는 데이터 추가
    row_dict["Name"] = "annellingM"
    
    # JSON 파일로 저장
    file_name = f"annellingM/Advs/{index}.json"
    with open(file_name, "w") as json_file:
        json.dump(row_dict, json_file, indent=4)


print("JSON 파일로 저장되었습니다.")

# 그래프 그리기
plt.plot(df)
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('meltingM')
plt.legend(df)
plt.grid(True)
plt.show()
# Out:
# JSON 파일로 저장되었습니다.

# %% [markdown]
# import matplotlib.pyplot as plt
#
# up = list(range(0, 520, 5))
# #up_slope = list(range(1, 10000, 10))
#
# up_slope = up_slope[:50]
# for i in range(len(up_slope)):
#     up[i+10] += up_slope[i]
# for i in range(len(up[10+len(up_slope):])):
#     up[10+len(up_slope)+i] += up_slope[49]
